# %% [markdown]
# <a href="https://colab.research.google.com/github/nadianaz0514-cloud/urdu-ocr-codesaviours-si26-Nadia/blob/main/SI26_Week1_Nadia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is OCR (Optical Character Recognition)?
#
# OCR (Optical Character Recognition) is a technology that helps computers read text from images, scanned papers, or photos. Instead of typing everything by hand, OCR can automatically convert the text into an editable digital format. It makes working with documents much faster and more convenient.
#
# 2. Why is Urdu OCR harder than English OCR?
#
# Urdu OCR is more challenging because Urdu is written in a connected script, and the shape of each letter can change depending on where it appears in a word. Many Urdu letters also look almost the same, with only small dots making the difference. Because of this, along with different fonts and handwriting styles, it is much harder for a computer to recognize Urdu text accurately.
#
# 3. What are 2 real-world situations where Urdu OCR would be useful?
#
# Urdu OCR would be very useful for converting old Urdu books, newspapers, and historical records into digital text so they can be searched and preserved. It can also help businesses and government offices quickly extract text from Urdu forms, invoices, or official documents without entering everything manually. This saves time and reduces mistakes.

# %%
# !pip install Pillow arabic-reshaper python-bidi
# !apt-get update -qq
# !apt-get install -y fonts-noto-core
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 9.9 MB/s eta 0:00:00
# ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-noto-core
# 0 upgraded, 1 newly installed, 0 to remove and 102 not upgraded.
# Need to get 12.2 MB of archives.
# After this operation, 43.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Fetched 12.2 MB in 2s (5,687 kB/s)
# Selecting previously unselected package fonts-noto-core.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../fonts-noto-core_20201225-1build1_all.deb ...
# ...

# %%
from PIL import Image, ImageDraw, ImageFont
import arabic_reshaper
from bidi.algorithm import get_display
import os

urdu_texts = [
    "پاکستان زندہ باد",
    "آج کا موسم خوشگوار ہے",
    "تعلیم ہر انسان کا حق ہے",
    "کراچی پاکستان کا سب سے بڑا شہر ہے",
    "محنت کامیابی کی کنجی ہے",
    "علم روشنی ہے",
    "وقت بہت قیمتی ہے",
    "محنت کا پھل میٹھا ہوتا ہے",
    "ہم سب پاکستانی ہیں",
    "صاف ماحول صحت کی ضمانت ہے",
    "درخت لگائیں ماحول بچائیں",
    "کتاب بہترین دوست ہے",
    "ہر انسان برابر ہے",
    "سچ ہمیشہ کامیاب ہوتا ہے",
    "پاکستان ایک خوبصورت ملک ہے",
    "اردو ہماری قومی زبان ہے",
    "پڑھائی کامیابی کی پہلی سیڑھی ہے",
    "ہمیں دوسروں کی مدد کرنی چاہیے",
    "دیانت داری بہترین پالیسی ہے",
    "اتحاد ایمان اور نظم"
]

os.makedirs("data/synthetic", exist_ok=True)

font = ImageFont.truetype(
    "/usr/share/fonts/truetype/noto/NotoNaskhArabic-Regular.ttf",
    32
)

for i, text in enumerate(urdu_texts):
    reshaped = arabic_reshaper.reshape(text)
    bidi_text = get_display(reshaped)

    img = Image.new("RGB", (700, 120), "white")
    draw = ImageDraw.Draw(img)

    bbox = draw.textbbox((0, 0), bidi_text, font=font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]

    x = 700 - text_width - 20
    y = (120 - text_height) // 2

    draw.text((x, y), bidi_text, fill="black", font=font)

    img.save(f"data/synthetic/urdu_{i+1}.png")

print(" 20 Synthetic Images Generated Successfully!")
# Out:
#  20 Synthetic Images Generated Successfully!

# %%
from google.colab import files
import shutil

shutil.make_archive("synthetic", "zip", "data/synthetic")
files.download("synthetic.zip")

# %%
import os

folders = [
    'data1/raw/newspaper',
    'data1/raw/books',
    'data1/raw/signboards',
    'data1/raw/synthetic',
    'data1/raw/other'
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')

print('Folder structure ready!')
# Out:
# Created: data1/raw/newspaper
# Created: data1/raw/books
# Created: data1/raw/signboards
# Created: data1/raw/synthetic
# Created: data1/raw/other
# Folder structure ready!

# %%
import csv

folder = 'book'

labels = [
    {'image': f'data/raw/{folder}/1.png', 'text': ''},
    {'image': f'data/raw/{folder}/14.png', 'text': ''},
    {'image': f'data/raw/{folder}/15.png', 'text': ''},
    {'image': f'data/raw/{folder}/16.png', 'text': ''},
    {'image': f'data/raw/{folder}/17.png', 'text': ''},
    {'image': f'data/raw/{folder}/18.png', 'text': ''},
    {'image': f'data/raw/{folder}/19.png', 'text': ''},
    {'image': f'data/raw/{folder}/21.png', 'text': ''},
    {'image': f'data/raw/{folder}/92.png', 'text': ''},
    {'image': f'data/raw/{folder}/93.png', 'text': ''},
    {'image': f'data/raw/{folder}/94.png', 'text': ''},
    {'image': f'data/raw/{folder}/95.png', 'text': ''},
    {'image': f'data/raw/{folder}/96.png', 'text': ''},
    {'image': f'data/raw/{folder}/97.png', 'text': ''},
    {'image': f'data/raw/{folder}/99.png', 'text': ''},
    {'image': f'data/raw/{folder}/100.png', 'text': ''},
    {'image': f'data/raw/{folder}/101.png', 'text': ''},
    {'image': f'data/raw/{folder}/102.png', 'text': ''},
    {'image': f'data/raw/{folder}/103.png', 'text': ''},
    {'image': f'data/raw/{folder}/104.png', 'text': ''},
]

with open(f'data/{folder}_labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'{folder} labels file created with {len(labels)} entries')
# Out:
# book labels file created with 20 entries

# %%
import csv

folder = 'others'

labels = [
    {'image': f'data/raw/{folder}/811.png', 'text': ''},
    {'image': f'data/raw/{folder}/812.png', 'text': ''},
    {'image': f'data/raw/{folder}/813.png', 'text': ''},
    {'image': f'data/raw/{folder}/814.png', 'text': ''},
    {'image': f'data/raw/{folder}/815.png', 'text': ''},
    {'image': f'data/raw/{folder}/820.png', 'text': ''},
    {'image': f'data/raw/{folder}/821.png', 'text': ''},
    {'image': f'data/raw/{folder}/822.png', 'text': ''},
    {'image': f'data/raw/{folder}/823.png', 'text': ''},
    {'image': f'data/raw/{folder}/829.png', 'text': ''},
    {'image': f'data/raw/{folder}/830.png', 'text': ''},
    {'image': f'data/raw/{folder}/831.png', 'text': ''},
    {'image': f'data/raw/{folder}/832.png', 'text': ''},
    {'image': f'data/raw/{folder}/838.png', 'text': ''},
    {'image': f'data/raw/{folder}/839.png', 'text': ''},
    {'image': f'data/raw/{folder}/840.png', 'text': ''},
    {'image': f'data/raw/{folder}/841.png', 'text': ''},
    {'image': f'data/raw/{folder}/847.png', 'text': ''},
    {'image': f'data/raw/{folder}/848.png', 'text': ''},
    {'image': f'data/raw/{folder}/849.png', 'text': ''},
]

with open(f'data/{folder}_labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'{folder} labels file created with {len(labels)} entries')
# Out:
# others labels file created with 20 entries

# %%
import csv

folder = 'synthetic'

labels = [
    {'image': f'data/raw/{folder}/urdu_1.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_2.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_3.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_4.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_5.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_6.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_7.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_8.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_9.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_10.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_11.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_12.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_13.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_14.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_15.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_16.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_17.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_18.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_19.png', 'text': ''},
    {'image': f'data/raw/{folder}/urdu_20.png', 'text': ''},
]

with open(f'data/{folder}_labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'{folder} labels file created with {len(labels)} entries')
# Out:
# synthetic labels file created with 20 entries

# %%
import csv

folder = 'signboards'

labels = [
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030243.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030248.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030256.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030423.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030754.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030803.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030809.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030816.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030822.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030847.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030902.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030910.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030922.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030943.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030950.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 031016.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 031021.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 031027.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 031033.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 031046.png', 'text': ''},
]

with open(f'data/{folder}_labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'{folder} labels file created with {len(labels)} entries')
# Out:
# signboards labels file created with 20 entries

# %%
import csv

folder = 'Newspaper'

labels = [
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030102.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030116.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030126.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030148.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030159.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030224.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030231.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030243.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030248.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030256.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030303.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030326.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030338.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030401.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030423.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030754.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030803.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030809.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030816.png', 'text': ''},
    {'image': f'data/raw/{folder}/Screenshot 2026-07-17 030822.png', 'text': ''},
]

with open(f'data/{folder}_labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'{folder} labels file created with {len(labels)} entries')
# Out:
# Newspaper labels file created with 20 entries
