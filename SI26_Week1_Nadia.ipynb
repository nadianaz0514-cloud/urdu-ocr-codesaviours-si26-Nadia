# %% [markdown]
# <a href="https://colab.research.google.com/github/nadianaz0514-cloud/urdu-ocr-codesaviours-si26-Nadia/blob/main/SI26_Week1_Nadia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is OCR (Optical Character Recognition)?
#
# OCR (Optical Character Recognition) is a technology that helps computers read text from images, scanned papers, or photos. Instead of typing everything by hand, OCR can automatically convert the text into an editable digital format. It makes working with documents much faster and more convenient.
#
# 2. Why is Urdu OCR harder than English OCR?
#
# Urdu OCR is more challenging because Urdu is written in a connected script, and the shape of each letter can change depending on where it appears in a word. Many Urdu letters also look almost the same, with only small dots making the difference. Because of this, along with different fonts and handwriting styles, it is much harder for a computer to recognize Urdu text accurately.
#
# 3. What are 2 real-world situations where Urdu OCR would be useful?
#
# Urdu OCR would be very useful for converting old Urdu books, newspapers, and historical records into digital text so they can be searched and preserved. It can also help businesses and government offices quickly extract text from Urdu forms, invoices, or official documents without entering everything manually. This saves time and reduces mistakes.

# %%
# !pip install Pillow arabic-reshaper python-bidi
# !apt-get update -qq
# !apt-get install -y fonts-noto-core
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 6.4 MB/s eta 0:00:00
# ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-noto-core
# 0 upgraded, 1 newly installed, 0 to remove and 129 not upgraded.
# Need to get 12.2 MB of archives.
# After this operation, 43.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Fetched 12.2 MB in 0s (41.7 MB/s)
# Selecting previously unselected package fonts-noto-core.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../fonts-noto-core_20201225-1build1_all.deb ...
# ...

# %%
from PIL import Image, ImageDraw, ImageFont
import arabic_reshaper
from bidi.algorithm import get_display
import os

urdu_texts = [
    "پاکستان زندہ باد",
    "آج کا موسم خوشگوار ہے",
    "تعلیم ہر انسان کا حق ہے",
    "کراچی پاکستان کا سب سے بڑا شہر ہے",
    "محنت کامیابی کی کنجی ہے",
    "علم روشنی ہے",
    "وقت بہت قیمتی ہے",
    "محنت کا پھل میٹھا ہوتا ہے",
    "ہم سب پاکستانی ہیں",
    "صاف ماحول صحت کی ضمانت ہے",
    "درخت لگائیں ماحول بچائیں",
    "کتاب بہترین دوست ہے",
    "ہر انسان برابر ہے",
    "سچ ہمیشہ کامیاب ہوتا ہے",
    "پاکستان ایک خوبصورت ملک ہے",
    "اردو ہماری قومی زبان ہے",
    "پڑھائی کامیابی کی پہلی سیڑھی ہے",
    "ہمیں دوسروں کی مدد کرنی چاہیے",
    "دیانت داری بہترین پالیسی ہے",
    "اتحاد ایمان اور نظم"
]

os.makedirs("data/synthetic", exist_ok=True)

font = ImageFont.truetype(
    "/usr/share/fonts/truetype/noto/NotoNaskhArabic-Regular.ttf",
    32
)

for i, text in enumerate(urdu_texts):
    reshaped = arabic_reshaper.reshape(text)
    bidi_text = get_display(reshaped)

    img = Image.new("RGB", (700, 120), "white")
    draw = ImageDraw.Draw(img)

    bbox = draw.textbbox((0, 0), bidi_text, font=font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]

    x = 700 - text_width - 20
    y = (120 - text_height) // 2

    draw.text((x, y), bidi_text, fill="black", font=font)

    img.save(f"data/synthetic/urdu_{i+1}.png")

print(" 20 Synthetic Images Generated Successfully!")
# Out:
#  20 Synthetic Images Generated Successfully!

# %%
from google.colab import files
import shutil

shutil.make_archive("synthetic", "zip", "data/synthetic")
files.download("synthetic.zip")

# %%
import os

folders = [
    'data2/raw/newspaper',
    'data2/raw/books',
    'data2/raw/signboards',
    'data2/raw/synthetic',
    'data2/raw/other'
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')

print('Folder structure ready!')
# Out:
# Created: data2/raw/newspaper
# Created: data2/raw/books
# Created: data2/raw/signboards
# Created: data2/raw/synthetic
# Created: data2/raw/other
# Folder structure ready!

# %%
import csv

labels = [
    {'image': 'data/raw/newspaper/811.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/812.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/813.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/814.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/815.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/820.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/821.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/822.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/823.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/829.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/830.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/831.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/832.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/838.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/839.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/840.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/841.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/847.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/848.png', 'text': 'ش'},
    {'image': 'data/raw/newspaper/849.png', 'text': 'ش'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030243.png', 'text': 'جیتنے کی پوری کوشش کی، آپ پر فخر: انگلینڈ کی شکست کے بعد شہزادہ ولیم کا جذباتی پیغام'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030243.png', 'text': 'فیفا ورلڈ کپ فٹبال کی افتتامی تقریب کا جشن میچ سے قبل منایا جائیگا'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030256.png', 'text': 'سائٹے 98 ہزار روپے کے ای چالان نادہندہ گاڑی پکڑی گئی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030256.png', 'text': 'فیروز والہ: گودام میں آتشزدگی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030256.png', 'text': 'والد، چچا اور دادا کو چاقو اور وار اور تشدد کرکے زخمی کرنے والا شخص گرفتار'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030423.png', 'text': 'پاکستان اور چین کا سی پیک 2.0، مصنوعی ذہانت اور ڈیجیٹل معیشت میں تعاون بڑھانے کا فیصلہ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030423.png', 'text': 'سیکیورٹی فورسز کی بنوں اور ملحقہ علاقوں میں کارروائیاں، 24 خوارج ہلاک'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030423.png', 'text': 'سرکاری جامعات میں بھرتیوں سے متعلق وفاقی آئینی عدالت کا اہم فیصلہ جاری'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030423.png', 'text': 'وزیر اعلیٰ کے پی سبیل آفریدی، جنید اکبر آفریدی اور عبدالغنی آفریدی کیخلاف اشتہاری قرار دینے کی کارروائی شروع'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030754.png', 'text': 'اسرائیلی پارلیمنٹ تحلیل کر دی گئی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030754.png', 'text': 'وینس نے کشنر و وٹکوف سے متعلق ایرانی انتہابی رپورٹ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030754.png', 'text': 'اینٹی ڈوپنگ قوانین کی خلاف ورزی، محمد نواز کو سزا سنا دی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030754.png', 'text': 'برطانیہ: ایرانی انٹیلی جنس کی معاونت کے الزام میں 1 شخص'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030754.png', 'text': 'اکشے کمار نے پاریش راول کو قانونی نوٹس کیوں بھیجا تھا؟'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030803.png', 'text': 'پاکستان آنے کے بعد 1 ماہ میں ڈرائیونگ کے 6 جرمانے ہو چکے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030803.png', 'text': 'ٹرمپ فیفا ورلڈ کپ کا فائنل اسٹیڈیم میں دیکھیں گے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030803.png', 'text': 'یوکرین کا بحیرہ اسود میں روس کے مزید 12 بحری جہازوں کو نشانہ بنانا'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030803.png', 'text': 'اردن میں موجود امریکی جنگی طیاروں کو نشانہ بنایا'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030803.png', 'text': 'جون میں کرنٹ اکاؤنٹ 64 کروڑ 90 لاکھ ڈالرز میں خسارے میں رہا'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030809.png', 'text': 'بہا سلیم کا کرکٹر پر ہراسانی کا الزام، قانونی کارروائی کا عندیہ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030809.png', 'text': '3 ایڈیٹس میں رنجھوڑ کا کردار سونم وانگ چ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030809.png', 'text': 'رجب بٹ کو کون جانتا ہے؟ فہد مصطفی بڑے بیرو ہیں'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030816.png', 'text': 'سیلینا جیٹلی نے ڈپریشن اور بچوں سے جدائی پر دل کا حال'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030816.png', 'text': 'بہا سلیم کا کرکٹر پر ہراسانی کا الزام، قانونی کارروائی کا عندیہ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030816.png', 'text': 'شہزاد نواز نے ٹیپو شریف کو جذباتی بیان پر حوصلہ دے دیا'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030816.png', 'text': 'رجب بٹ کو کون جانتا ہے؟ فہد مصطفی بڑے بیرو ہیں'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030816.png', 'text': 'کترینہ کیف نے چند سال میں 350 کروڑ سے زائد مالیت کا اضافہ کیا'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030822.png', 'text': 'کیا روہت شرما کا انگلینڈ سیریز کا آئندہ میچ آخری ون ڈے ہو گا؟'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030822.png', 'text': 'کیا وہم کے باعث صدر ارجنٹینا ورلڈ کپ فائنل میں شرکت نہیں کریں گے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030822.png', 'text': "فیفا ورلڈ کپ: 'سیاسی بینر' آویزاں کرنے پر ارجنٹینا پر خیال"},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030822.png', 'text': 'فیفا ورلڈکپ: ارجنٹینا کے سب سے زیادہ فاؤلز لیکن کم یلو کارڈ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030822.png', 'text': 'انتہا پسند اسرائیلی وزیر فیفا ورلڈ کپ میں ارجنٹینا کی فتح پر ناخوش'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030822.png', 'text': 'کوئی بھی ہمیں مفت میں کچھ نہیں دیتا'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030847.png', 'text': 'ملک بھر میں آٹے کی سپلائی متاثر، 10 اور 20 کلو کے تھیلے نایاب'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030847.png', 'text': 'پنجاب سے آٹے اور گندم کی اسمگلنگ روکنے کیلئے راولپنڈی کے داخلی و خارجی راستوں پر 9 چیک پوسٹیں قائم'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030847.png', 'text': 'علامہ سید عقیل الغروی مجلس عزا سے خطاب کریں گے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030847.png', 'text': 'پاکستانی طلبہ نے 56 ویں انٹرنیشنل فزکس اولمپیاڈ میں تین کانسی کے تمغے جیت لیے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030847.png', 'text': 'حق ملکیت کو آئین کے تحت تحفظ حاصل ہے، رضا ربانی'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030902.png', 'text': 'خواجہ ناصر علی ڈائریکٹر آڈٹ سی ڈی اے تعینات'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030902.png', 'text': 'آزاد کشمیر، بلوچستان صورتحال تشویشناک، حکومت حالات کا ادراک کرے، حافظ نعیم'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030902.png', 'text': 'راولپنڈی، مختلف واقعات میں 2 افراد نے خودکشی کر لی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030902.png', 'text': 'راولپنڈی، سی پی او کا شہر کے مختلف علاقوں کا دورہ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030902.png', 'text': 'ایف جی ای اے نے جی 13-14 میں تجاوزات کیخلاف آپریشن شروع کردیا'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030902.png', 'text': 'راولپنڈی کے شہری گاڑی 13 موٹر سائیکلوں سے محروم ہوگئے'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030910.png', 'text': 'راولپنڈی میں فوڈ ٹیسٹنگ لیبارٹری اینڈ ٹریننگ سکول قائم کرنے کا فیصلہ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030910.png', 'text': 'شمالی علاقوں میں لینڈ سلائیڈنگ اور اچانک سیلاب کا سلسلہ جاری'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030910.png', 'text': 'ڈسٹرکٹ ہیلتھ اتھارٹی کے 73 کنٹریکٹ ملازمین کو فارغ کرنے کا فیصلہ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030910.png', 'text': 'راولپنڈی، خود کو پرائس مجسٹریٹ ظاہر کرنیوالا جعلساز گرفتار'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030910.png', 'text': 'عبادت کے روز مسیحی سینیٹری ورکرز کو کام پر بلانے پر سی ڈی اے سے جواب طلب'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030922.png', 'text': 'فیک نیوز کا مقابلہ حقائق پر مبنی خبروں سے کیا جا سکتا ہے، طاہر خلیل'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030922.png', 'text': 'راولپنڈی میں مختلف واقعات، بچوں سے زیادتی کرنیوالے دو افراد گرفتار'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030922.png', 'text': 'اسلام آباد پولیس نے 25 جرائم پیشہ عناصر گرفتار کر لئے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030922.png', 'text': 'راولپنڈی، سی پی او نے 2 ایس ایچ او تبدیل کردیا'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030922.png', 'text': 'راولپنڈی، مختلف واقعات، نو عمر لڑکے اور خاتون سمیت 4 افراد جان کی بازی ہار گئے'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030943.png', 'text': 'کیا الیکٹرک ہوائی جہاز کا تصور حقیقت کا روپ دھار با؟'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030943.png', 'text': 'خواتین کیلئے اپنے کاروبار میں کامیابی کے مواقع'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030943.png', 'text': 'نئی ٹیکنالوجی عدم مساوات کی وجہ نہیں بلکہ حل ہے'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030950.png', 'text': 'مینجمنٹ جاب اور اچھا منیجر'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030950.png', 'text': 'ترقیاتی کاموں سے آگاہی کا عالمی دن'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_030950.png', 'text': 'انٹرنیشنل مانیٹری فنڈ (آئی ایم ایف) کیا کرتا ہے؟'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031016.png', 'text': 'کالعدم کمیٹی سے بات کرکے مسائل حل کیے جائیں، فضل الرحمٰن'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031016.png', 'text': 'پاکستان اور چین کا سی پیک 2.0، تجارت، سرمایہ کاری میں تعاون بڑھانے پر اتفاق'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031016.png', 'text': 'کراچی: بی آر ٹی ریڈلائن منصوبے، حادثے میں آنکھ ضائع ہونے پر شہری کا 17 کروڑ ہرجانے کا دعویٰ'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031016.png', 'text': 'ہارٹ: مولانا محمد علی جوہر یونیورسٹی کے 38 لاکھ گرانے کا حکم'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031016.png', 'text': 'امریکہ اور ایران کے ایک دوسرے پر حملے، عالمی منڈیوں میں تیل کی قیمتیں بڑھنے لگیں'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031021.png', 'text': 'مالی تنگدستی نے چھوٹی عمر میں سمجھدار بنادیا تھا، وجے سیتھوپتی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031021.png', 'text': 'بھارت: بوائے فرینڈ سے تعلق ختم کرنے پر قانون کی طالبہ کو قتل کردیا گیا'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031021.png', 'text': 'ورلڈ آرٹیفیشل انٹیلی جنس آرگنائزیشن کا قیام، پاکستان نے دستخط کردیے'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031021.png', 'text': 'واشنگٹن: محسن نقوی کی بوئنگ کمپنی کے صدر سے ملاقات، 16 نئے طیاروں کی خریداری پر بات چیت'},

    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031027.png', 'text': 'جی بی اسمبلی: پاک فوج کے شہداء کے حق میں قرارداد منظور، مولانا فضل الرحمٰن کے بیان کی مذمت'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_031027.png', 'text': 'حوثیوں نے سعودی تنصیبات کو نشانہ بنانے کی دھمکی دے دی'},
    {'image': 'data/raw/newspaper/Screenshot_2026-07-17_
    {'image': 'data/raw/newspaper/img003.jpg',
     'text': 'کیخلاف جنگ میں کامیابی کے بعد پاکستانی بتھیاروں کی عالمی مانگ میں اضافہ\nمئی کی جھڑپ کے بعد پاکستانی ساختہ جے ایف ڈی سمیت دفاعی سازوسامان نے عالمی توجہ حاصل کی، سعودی عرب، بنگلہ دیش اور لیبیا کے ساتھ معاہدات جاری ہیں۔\nبلاگ\nپی آئی اے نجکاری کے بعد آمدنی میں اضافے کے پاکستان ایوی ایشن پلان'},

    {'image': 'data/raw/newspaper/img004.jpg',
     'text': "دنیا\nترکیہ پاکستان اور سعودی عرب کے باہمی دفاعی معاہدے میں شمولیت کا خواہاں، نیا سیکیورٹی اتحاد متوقع\nبلومبرگ کے مطابق ترکیہ کی شمولیت سے پاکستان، سعودی عرب اور ترکیہ کے درمیان دفاعی تعاون کا نیا محور بن سکتا ہے، جو خطے میں طاقت کے توازن کو متاثر کرے گا۔\nلانف اسٹائل\n'دہرندر' کو مشرق وسطیٰ کے کئی ممالک میں پابندی کا سامنا\nبھارتی میڈیا کے مطابق یہ فلم چھ ممالک بحرین، کویت، عمان، قطر، سعودی عرب اور متحدہ عرب امارات میں ریلیز ہونے سے روک دی گئی ہے۔ شائع 12 دسمبر 2025 04:19pm"},

    {'image': 'data/raw/newspaper/img005.jpg',
     'text': 'دنیا\nایران میں مہنگائی کے خلاف احتجاج شدت اختیار کرگیا، انٹرنیٹ سروس بند، پروازیں منسوخ\nمظاہروں کے دوران 34 مظاہرین اور 4 سیکیورٹی اہلکار جاں بحق، دو ہزار سے زائد افراد گرفتار، آیت اللہ خامنہ ای کا ٹرمپ کو اپنے ملکی معاملات پر توجہ دینے کا مشورہ\nلانف اسٹائل\nبرطانیہ نے معروف یوٹیوبر رچب بٹ کو ملک بدر'},

    {'image': 'data/raw/newspaper/img006.jpg',
     'text': 'سحل علی کے ڈرامے پر تنقید، صبا فیصل صبا نادیہ خان کیخلاف بول پڑیں\nJUL 17, 2026 | 13:39\nاداکارہ نادیہ خان ان دنوں شدید تنقید کی زد میں ہیں۔ نادیہ نے ایک ڈرامے کے سین پر تبصرہ کیا تھا کہ اداکارہ سحل علی کا کردار بچے سے خطرناک ہے۔\nبھارتی اداکارہ شہناز گل نے راگھو جویل کے ساتھ ڈیٹنگ افواہوں پر خاموشی توڑ دی\nJUL 17, 2026 | 13:33\nبنوں اور اطراف میں سیکیورٹی فورسز کی کارروائیاں، بھارتی پراکسی فتنہ الخوارج کے 24 دہشتگرد۔۔۔\nJUL 17, 2026 | 13:28\nپاکستان اسٹاک مارکیٹ میں مندی کا رجحان، ڈالر کی قدر مستحکم\nJUL 17, 2026 | 13:23'},

    {'image': 'data/raw/newspaper/img007.jpg',
     'text': 'اسرائیل کو تسلیم نہیں کرتے، ملائیشیا میں کوئی اسرائیلی پایا گیا تو اسے فوراً ملک بدر کیا جائے گا: انور ابراہیم\nJUL 17, 2026 | 13:30\nملائیشیا کے وزیراعظم انور ابراہیم نے کہا ہے کہ اگر ملک میں کوئی اسرائیلی شہری پایا گیا تو اسے فوری طور پر ملک بدر کر دیا جائے گا۔ انور ابراہیم نے کہا\nجان سے مارنے کی دھمکیاں، عامر خان نے اپنی تیسری اہلیہ کا مذہب بتادیا\nJUL 17, 2026 | 13:31\nآبنائے ہرمز کے بحران سے عالمی توانائی کی سلامتی کو سنگین خطرہ ہے: عالمی توانائی ایجنسی\nJUL 17, 2026 | 13:14\nخوفناک ٹریفک حادثہ، 20 بچے ہلاک'},

    {'image': 'data/raw/newspaper/img008.jpg',
     'text': 'ارجنٹینا کیخلاف شکست پر انگلش فٹبال ہیڈ۔۔۔\nJUL 17, 2026 | 10:44\nفیفا ورلڈ کپ 2026 کے سیمی فائنل میں ارجنٹینا کے ہاتھوں 2-1 کی شکست کے بعد انگلینڈ کے ہیڈ کوچ تھامس ٹوخل نے کہا کہ اس طرح کی شکست کا درد ہمیشہ زیادہ ہوتا ہے۔ میچ کے بعد پریس کانفرنس میں تھامس ٹوخل نے کہا۔۔۔\nجیتنے کی پوری کوشش کی، آپ پر فخر: انگلینڈ کی شکست کے بعد شہزادہ ولیم کا جذباتی پیغام\nJUL 17, 2026\nفیفا ورلڈ کپ فٹبال کی اختتامی تقریب کا جشن میچ سے قبل منایا جائے گا\nJUL 17, 2026\nکھلیوں کا فروغ، ٹیلنٹ کی تلاش، پنجاب رائزنگ سٹارز پورٹل پر۔۔۔'},

    {'image': 'data/raw/newspaper/img009.jpg',
     'text': 'سمیت نہر میں کودنے کے ۔۔۔ کی تلاش تاحال جاری ہے۔ درج کر لیا گیا ہے۔ ترجمان\nخاتون نادہندہ گاڑی پکڑی گئی'},

    {'image': 'data/raw/newspaper/img010.jpg',
     'text': 'گزشتہ روز خاتون کی جانب سے اپنے چار بچوں سمیت نہر میں کودنے کے افسوسناک واقعے کے 2 بچوں کی تلاش تاحال جاری ہے، جبکہ والد کی مدعیت میں والدہ کیخلاف مقدمہ درج کر لیا گیا ہے۔ ترجمان۔۔۔\nسائٹے 98 ہزار روپے کے ای چالان نادہندہ گاڑی پکڑی گئی\nJUL 17, 2026\nفیروزوالہ: گودام میں آتشزدگی\nJUL 17, 2026\nوالد پھپا اور دادا کو چاقو اور وار اور تشدد کرکے زخمی کرنے والا شخص گرفتار\nJUL 17, 2026'},

    {'image': 'data/raw/newspaper/img011.jpg',
     'text': 'یوگنڈا میں ایک بس حادثے میں کم از کم 20 بچے ہلاک ہو گئے۔ میڈیا رپورٹس کے مطابق حادثہ اس وقت پیش آیا جب بھری سکول بس دارالحکومت کمپالا جا رہی تھی۔ مقامی پولیس نے اسکس پر بتایا ڈرائیور نے میدینہ۔۔۔\nپنجاب پولیس شہداء کی عظیم قربانی کو کبھی فراموش نہیں کریگی: آئی جی پنجاب\nJUL 17, 2026\nشیشہ فلیور سے بھرا رکشہ پکڑا گیا، منفیات فروشوں سمیت 8 ہواری گرفتار\nJUL 17, 2026\nچرس اور اسلحہ معہ ایوونیشن برآمد\nJUL 17, 2026'},

    {'image': 'data/raw/newspaper/textbox_30_line_1_.png', 'text': 'ہوٹل کا کھانا مزے کا تھا۔'},
    {'image': 'data/raw/newspaper/textbox_30_line_2_.png', 'text': 'یہاں کمرے میں چائے'},
    {'image': 'data/raw/newspaper/textbox_31_line_1_.png', 'text': 'نے پلائی گئی۔'},
    {'image': 'data/raw/newspaper/textbox_31_line_2_.png', 'text': 'سٹاف نہایت دوستانہ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_32_line_1_.png', 'text': 'ہوٹل کا واش روم صاف نہیں تھا۔'},
    {'image': 'data/raw/newspaper/textbox_32_line_2_.png', 'text': 'صفائی کا کوئی'},
    {'image': 'data/raw/newspaper/textbox_3_line_1_.png', 'text': 'خیال نہیں رکھا گیا۔'},
    {'image': 'data/raw/newspaper/textbox_3_line_2_.png', 'text': 'رینٹ بہت زیادہ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_4_line_1_.png', 'text': 'ہوٹل کا عملہ دوستانہ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_4_line_2_.png', 'text': 'ہمارا سامان کاڑی سے'},
    {'image': 'data/raw/newspaper/textbox_5_line_2_.png', 'text': 'کمرے کی چابی دی گئی۔'},
    {'image': 'data/raw/newspaper/textbox_5_line_3_.png', 'text': 'یہیں صفت میں جانے پہلی'},
    {'image': 'data/raw/newspaper/textbox_6_line_1_.png', 'text': 'ہوٹل کا سٹاف اور عملہ نہایت اچھا اور دوستانہ'},
    {'image': 'data/raw/newspaper/textbox_6_line_2_.png', 'text': 'ہے۔'},
    {'image': 'data/raw/newspaper/textbox_7_line_2_.png', 'text': 'کمرے کے مکمل صاف اور کھانا اور منظر'},
    {'image': 'data/raw/newspaper/textbox_7_line_3_.png', 'text': 'کا'},
    {'image': 'data/raw/newspaper/textbox_8_line_1_.png', 'text': 'ہوٹل کی کمرہ میں کھلتی ہے۔'},
    {'image': 'data/raw/newspaper/textbox_8_line_2_.png', 'text': 'ہوٹل میں اچھے بیڈ'},
    {'image': 'data/raw/newspaper/textbox_9_line_1_.png', 'text': 'ہوٹل کا رینٹ بہت'},
    {'image': 'data/raw/newspaper/textbox_9_line_2_.png', 'text': 'زیادہ ہے۔'},

    {'image': 'data/raw/newspaper/textbox_16_line_1_.png', 'text': 'ہوٹل کا عملہ کافی دوستانہ ہے۔ ہوٹل سے'},
    {'image': 'data/raw/newspaper/textbox_16_line_2_.png', 'text': 'کھیل کا منظر خوبصورت نظر آتا ہے۔'},
    {'image': 'data/raw/newspaper/textbox_17_line_1_.png', 'text': 'ہوٹل کا کھانا مہینوی اور یہیں منظرے کا تھا۔'},
    {'image': 'data/raw/newspaper/textbox_17_line_2_.png', 'text': 'ہوٹل کا سٹاف خوش شگفتہ اور دوستانہ نہ تھا۔'},
    {'image': 'data/raw/newspaper/textbox_18_line_1_.png', 'text': 'صبح کے وقت واش روم میں گرم پانی نہیں آ رہا تھا۔'},
    {'image': 'data/raw/newspaper/textbox_1_line_1_.png', 'text': 'ہوٹل کا عملہ نہایت دوستانہ ہے۔ عملہ نے'},
    {'image': 'data/raw/newspaper/textbox_1_line_2_.png', 'text': 'میری بہت مدد کی۔ میں یہاں ضرور واپس آؤں گا۔'},
    {'image': 'data/raw/newspaper/textbox_2_line_1_.png', 'text': 'ہوٹل کی فضا خوشگوار ہے۔ ہوٹل کا ماحول'},
    {'image': 'data/raw/newspaper/textbox_2_line_2_.png', 'text': 'خوشگوار ہے۔ ہوٹل کا عملہ دوستانہ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_34_line_2_.png', 'text': 'ہوٹل کا سٹاف اچھا ہے۔ یہیں بہت انتظار'},
    {'image': 'data/raw/newspaper/textbox_34_line_3_.png', 'text': 'کروایا۔ میں دوبارہ اس ہوٹل میں نہیں آؤں گا۔'},
    {'image': 'data/raw/newspaper/textbox_35_line_1_.png', 'text': 'میں نے ہوٹل میں دو کمروں کی بکنگ کروائی'},
    {'image': 'data/raw/newspaper/textbox_35_line_2_.png', 'text': 'ہوٹل آکر مجھے صرف ایک کمرہ دیا گیا۔'},
    {'image': 'data/raw/newspaper/textbox_36_line_1_.png', 'text': 'ہوٹل دیکھنے میں بہت خوبصورت ہے۔ ہوٹل کا'},
    {'image': 'data/raw/newspaper/textbox_36_line_2_.png', 'text': 'احاطہ کافی بڑا ہے۔ ہوٹل کا کھانا لذیذ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_37_line_1_.png', 'text': 'ہوٹل کا کھانا مزیدار تھا۔ ہوٹل کا کھانا'},
    {'image': 'data/raw/newspaper/textbox_37_line_2_.png', 'text': 'معیاری تھا۔ ہوٹل کا ماحول خوشگوار تھا۔'},
    {'image': 'data/raw/newspaper/textbox_38_line_1_.png', 'text': 'ہوٹل کی پارکنگ بہت بڑی ہے۔ ہوٹل کی سیکیورٹی'},
    {'image': 'data/raw/newspaper/textbox_38_line_2_.png', 'text': 'کا نظام بہت اچھا ہے۔ ہوٹل کا کھانا لذیذ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_39_line_2_.png', 'text': 'ہوٹل کا رینٹ بہت زیادہ ہے۔'},

    # ==================== NEW ENTRIES (100 images added from data2.zip) ====================

    # --- Newspaper/ : 20 new screenshots (2026-07-27 batch) ---
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 010803.png', 'text': ''},  # VERIFY: full article body, multi-paragraph
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 010822.png', 'text': 'چھ ارب ڈالر: کارگو کی مالیت، وصول شدہ رقم نہیں'},  # VERIFY: headline read; body paragraphs not transcribed
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 010845.png', 'text': ''},  # VERIFY: full article body
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 010905.png', 'text': ''},  # VERIFY: multi-headline live-update style screenshot
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 010917.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011403.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011443.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011502.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011524.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011708.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011726.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011744.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 011750.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012303.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012315.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012329.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012436.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012505.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012517.png', 'text': ''},  # VERIFY
    {'image': 'data2/Newspaper/Screenshot 2026-07-27 012529.png', 'text': ''},  # VERIFY

    # --- others/ : 20 new single-character crops (28x28) ---
    {'image': 'data2/others/1.png', 'text': 'ھ'},    # VERIFY: guessed from shape (hook + loop)
    {'image': 'data2/others/2.png', 'text': 'ھ'},    # VERIFY
    {'image': 'data2/others/3.png', 'text': 'ھ'},    # VERIFY
    {'image': 'data2/others/4.png', 'text': 'ھ'},    # VERIFY
    {'image': 'data2/others/15.png', 'text': 'ج'},   # VERIFY: guessed from shape (loop with inner dot)
    {'image': 'data2/others/16.png', 'text': 'ج'},   # VERIFY
    {'image': 'data2/others/17.png', 'text': 'ج'},   # VERIFY
    {'image': 'data2/others/18.png', 'text': 'ج'},   # VERIFY
    {'image': 'data2/others/19.png', 'text': 'ج'},   # VERIFY
    {'image': 'data2/others/54.png', 'text': 'ر'},   # VERIFY: guessed from shape (curved hook, no dot)
    {'image': 'data2/others/55.png', 'text': 'ر'},   # VERIFY
    {'image': 'data2/others/56.png', 'text': 'ر'},   # VERIFY
    {'image': 'data2/others/57.png', 'text': 'ر'},   # VERIFY
    {'image': 'data2/others/58.png', 'text': 'ر'},   # VERIFY
    {'image': 'data2/others/59.png', 'text': 'ر'},   # VERIFY
    {'image': 'data2/others/225.png', 'text': 'ڑ'},  # VERIFY: guessed from shape (fishhook curve)
    {'image': 'data2/others/226.png', 'text': 'ڑ'},  # VERIFY
    {'image': 'data2/others/227.png', 'text': 'ڑ'},  # VERIFY
    {'image': 'data2/others/228.png', 'text': 'ڑ'},  # VERIFY
    {'image': 'data2/others/229.png', 'text': 'ڑ'},  # VERIFY

    # --- signboards/ : 20 new screenshots (2026-07-27 235xxx batch) ---
    {'image': 'data2/signboards/Screenshot 2026-07-27 235632.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235645.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235705.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235713.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235720.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235728.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235731.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235739.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235745.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235756.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235806.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235816.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235857.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235902.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235910.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235918.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235927.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235931.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235939.png', 'text': ''},  # VERIFY
    {'image': 'data2/signboards/Screenshot 2026-07-27 235956.png', 'text': ''},  # VERIFY

    # --- synthetic/ : 20 new images (urdu_179 to urdu_199, skipping 189) ---
    {'image': 'data2/synthetic/urdu_179.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_180.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_181.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_182.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_183.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_184.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_185.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_186.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_187.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_188.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_190.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_191.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_192.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_193.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_194.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_195.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_196.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_197.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_198.png', 'text': ''},  # VERIFY
    {'image': 'data2/synthetic/urdu_199.png', 'text': ''},  # VERIFY

    # --- book/ : 20 new screenshots (2026-07-27 04xxxx batch) ---
    {'image': 'data2/book/Screenshot 2026-07-27 040812.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 040827.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 040911.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 040931.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 040947.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 040953.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041002.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041012.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041036.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041144.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041216.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041301.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041438.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041441.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041449.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041453.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041506.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041514.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041551.png', 'text': ''},  # VERIFY
    {'image': 'data2/book/Screenshot 2026-07-27 041622.png', 'text': ''},  # VERIFY

    # Note: data2.zip also contained book/textbox_*.png files (e.g. textbox_30_line_1_.png,
    # textbox_1_line_1_.png, etc.) with filenames identical to ones already labeled above under
    # data/raw/newspaper/ — these look like duplicates of already-labeled images, so they were
    # NOT re-added here. If they're actually different crops, tell me and I'll add them separately.
]

with open('data2/labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'Labels file created with {len(labels)} entries')
# Out:
# Labels file created with 264 entries
